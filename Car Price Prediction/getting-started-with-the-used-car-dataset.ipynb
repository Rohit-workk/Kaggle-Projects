# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/used-car-price-prediction/Used_Car_Price_Prediction.csv

# %%
df = pd.read_csv("/kaggle/input/used-car-price-prediction/Used_Car_Price_Prediction.csv")
df
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# ...

# %% [markdown]
#
#
# ---
#
# ## 📌 Dataset Overview
# Each row in the dataset represents a **unique used car listing** with details such as make, model, year of manufacture, price, ownership, and other listing metadata.
#
# ---
#
# ## 📑 Columns Description
#
# | Column | Description |
# |--------|-------------|
# | **car_name** | Name of the car (make + model, e.g., *Maruti Swift*, *Hyundai i10*). |
# | **yr_mfr** | Year of manufacture of the car. |
# | **fuel_type** | Type of fuel used (*Petrol, Diesel, CNG, Electric*, etc.). |
# | **kms_run** | Kilometers driven by the car (odometer reading). |
# | **sale_price** | Final listed selling price of the car (**target column for regression**). |
# | **city** | City where the car is listed. |
# | **times_viewed** | Number of times the listing was viewed online. |
# | **body_type** | Body type of the car (*Hatchback, Sedan, SUV*, etc.). |
# | **transmission** | Gear type (*Manual / Automatic*). |
# | **variant** | Variant of the car (e.g., *LXI, VDI, Sports*). |
# | **assured_buy** | Whether the car comes with an assured buy option (*True/False*). |
# | **registered_city** | City where the car is registered. |
# | **registered_state** | State where the car is registered. |
# | **is_hot** | Indicates if the car is a “hot” listing (highly demanded). |
# | **rto** | Regional Transport Office code of the registration. |
# | **source** | Source platform of the listing. |
# | **make** | Manufacturer of the car (e.g., *Maruti, Hyundai, Honda*). |
# | **model** | Model name of the car (e.g., *Swift, i10, City*). |
# | **car_availability** | Availability status of the car (*Available / Sold*). |
# | **total_owners** | Number of previous owners (*1, 2, 3*, etc.). |
# | **broker_quote** | Price quoted by broker/agent. |
# | **original_price** | Original on-road price when the car was new. |
# | **car_rating** | Rating of the car’s condition (*Excellent, Good, Fair*, etc.). |
# | **ad_created_on** | Date and time when the ad was created. |
# | **fitness_certificate** | Whether the car has a valid fitness certificate (*True/False*). |
# | **emi_starts_from** | Monthly EMI amount if financed. |
# | **booking_down_pymnt** | Minimum down payment required for booking. |
# | **reserved** | Whether the car is already reserved (*True/False*). |
# | **warranty_avail** | Availability of warranty (*True/False*). |
#
# ---

# %%
# LETS UNDERSTAND ABOUT DATASET
print(f"shape of dataset is {df.shape}")
print("\n ======================================================================\n")
print(f"columns present in the dataset are {df.columns}")
print("\n ======================================================================\n")
print(f"columns present in the dataset with there datatypes\n {df.dtypes}")
print("\n ======================================================================\n")
print(f"information about dataset \n {df.info()}")
print("\n ======================================================================\n")
print(f"data discritbtion of every numerical feature \n{df.describe()}")
print("\n ======================================================================\n")
print(f"data describtion of non numerical datatype \n {df.describe(include=['float64','int64'])}")
print("\n ======================================================================\n")
print(f"numercial columns in dataset are {df.select_dtypes(include = ['float','int']).columns.to_list()}")
print("\n ======================================================================\n")
print(f"non numerical columns in dataset are {df.select_dtypes(include = 'O').columns.to_list()}")
# Out:
# shape of dataset is (7400, 29)
#
# ...
#
# columns present in the dataset are Index(['car_name', 'yr_mfr', 'fuel_type', 'kms_run', 'sale_price', 'city',
#        'times_viewed', 'body_type', 'transmission', 'variant', 'assured_buy',
#        'registered_city', 'registered_state', 'is_hot', 'rto', 'source',
#        'make', 'model', 'car_availability', 'total_owners', 'broker_quote',
#        'original_price', 'car_rating', 'ad_created_on', 'fitness_certificate',
#        'emi_starts_from', 'booking_down_pymnt', 'reserved', 'warranty_avail'],
#       dtype='object')
#
# ...
#
# columns present in the dataset with there datatypes
#  car_name                object
# yr_mfr                   int64
# fuel_type               object
# kms_run                  int64
# sale_price               int64
# city                    object
# times_viewed             int64
# body_type               object
# transmission            object
# variant                 object
# assured_buy               bool
# ...

# %%
# LETS CHECK THE NULL VALUES AND DUPLICATES
# LETS DISTRIBUTE COLUMNS WITH ON VALUES DISTRIBUTION FOR EASY VISULIZATION
catcol = []
numcol = []
midcol = []
for col in df.columns:
    if df[col].isna().sum() == 0:
        print(f"THERE NO NULL VALUES PRESENT IN {col}")
        
        # lets check for values
        val = df[col].nunique()
        
        print(f"NUMBER OF UNIQUE VALUES PRESENT IN {col} ARE = {val}")
        if (val >0 and val<12):
            catcol.append(col)
        elif(val>12 and val<50):
            midcol.append(col)
        else:
            numcol.append(col)
        
        print("\n"+"="*80+"\n")
    else:
        print(f"IN {col} HAS NULL VALUES ")
        print(f"NULL VALUES PERCENTAGE {df[col].isna().mean()*100}%")
        print(f"NULL VALUES /TOTAL VALUES = {df[col].isna().sum()}/{df[col].count()}")

        val = df[col].nunique()
        
        print(f"NUMBER OF UNIQUE VALUES PRESENT IN {col} ARE = {val}")
        if (val >0 and val<12):
            catcol.append(col)
        elif(val>12 and val<50):
            midcol.append(col)
        else:
            numcol.append(col)

        print("\n"+"="*80+"\n")

print(f"numercail columns are {numcol}\n")
print(f"categorical columns are {catcol}\n")
print(f"mid values columns are {midcol}\n")
# Out:
# THERE NO NULL VALUES PRESENT IN car_name
# NUMBER OF UNIQUE VALUES PRESENT IN car_name ARE = 185
#
# ...
#
# THERE NO NULL VALUES PRESENT IN yr_mfr
# NUMBER OF UNIQUE VALUES PRESENT IN yr_mfr ARE = 24
#
# ...
#
# THERE NO NULL VALUES PRESENT IN fuel_type
# NUMBER OF UNIQUE VALUES PRESENT IN fuel_type ARE = 5
#
# ...
#
# THERE NO NULL VALUES PRESENT IN kms_run
# NUMBER OF UNIQUE VALUES PRESENT IN kms_run ARE = 7176
#
# ...
#
# THERE NO NULL VALUES PRESENT IN sale_price
# NUMBER OF UNIQUE VALUES PRESENT IN sale_price ARE = 4519
#
# ...
#
# THERE NO NULL VALUES PRESENT IN city
# NUMBER OF UNIQUE VALUES PRESENT IN city ARE = 13
#
# ...
#
# THERE NO NULL VALUES PRESENT IN times_viewed
# NUMBER OF UNIQUE VALUES PRESENT IN times_viewed ARE = 3151
#
# ...
#
# IN body_type HAS NULL VALUES
# NULL VALUES PERCENTAGE 1.3918918918918919%
# NULL VALUES /TOTAL VALUES = 103/7297
# NUMBER OF UNIQUE VALUES PRESENT IN body_type ARE = 5
#
# ...
#
# IN transmission HAS NULL VALUES
# NULL VALUES PERCENTAGE 7.513513513513513%
# ...

# %% [markdown]
# # 🔎 Dataset Observations
#
# The dataset contains **7400 rows × 29 columns** describing used car listings.
# It includes a mix of **numerical, categorical, boolean, and datetime-like features**.
#
# ---
#
# ## 📐 Dataset Shape
# - **Rows:** 7400
# - **Columns:** 29
#
# ---
#
# ## 🧾 Data Types Overview
# - **Numerical Columns (9):** `yr_mfr`, `kms_run`, `sale_price`, `times_viewed`, `total_owners`, `broker_quote`, `original_price`, `emi_starts_from`, `booking_down_pymnt`
# - **Categorical Columns (12):** `fuel_type`, `body_type`, `transmission`, `assured_buy`, `is_hot`, `source`, `car_availability`, `car_rating`, `fitness_certificate`, `reserved`, `warranty_avail`, `city/make/state` (mixed)
# - **Boolean Columns (4):** `assured_buy`, `is_hot`, `reserved`, `warranty_avail`
# - **String/Identifier Columns (4+):** `car_name`, `variant`, `model`, `rto`, etc.
# - **Datetime-like Column:** `ad_created_on`
#
# ---
#
# ## 🧮 Numerical Feature Insights
#
# - **Year of Manufacture (`yr_mfr`):**
#   - Range: 1996 – 2021
#   - Avg: ~2014 → most cars are relatively new.
#
# - **Kilometers Run (`kms_run`):**
#   - Range: 60 – 996,609 km
#   - Avg: ~62,624 km → dataset covers both low and high mileage cars.
#
# - **Sale Price (`sale_price`):**
#   - Range: ₹0 – ₹38.66 lakh
#   - Avg: ~₹4.55 lakh → most cars are in the affordable/midrange category.
#   - Target column for regression.
#
# - **Times Viewed (`times_viewed`):**
#   - Range: 3 – 61,930 views
#   - Median: ~1,088 views → listing popularity is highly skewed.
#
# - **Owners (`total_owners`):**
#   - Range: 1 – 6
#   - Median: 1 → majority are first-owner cars.
#
# - **Broker Quote vs Sale Price:**
#   - Broker quotes (`broker_quote`) have similar distribution to `sale_price`.
#   - Useful for comparative pricing analysis.
#
# - **Original Price (`original_price`):**
#   - Available for ~55% of records (missing 44.3%).
#   - Range: ₹96,890 – ₹27.65 lakh.
#
# - **Loan/EMI-related (`emi_starts_from`, `booking_down_pymnt`):**
#   - Avg EMI: ~₹10,566
#   - Avg Down Payment: ~₹68,233
#   - Indicates financing options are common in listings.
#
# ---
#
# ## 🏷️ Categorical Feature Insights
#
# - **Car Name (`car_name`):**
#   - 185 unique values (make + model).
#   - Rich variety of brands and models.
#
# - **Fuel Type (`fuel_type`):**
#   - 5 categories → Petrol, Diesel, CNG, Electric, etc.
#   - Balanced distribution expected but likely skewed to Petrol/Diesel.
#
# - **City (`city`):**
#   - 13 unique cities → dataset covers multiple metro markets.
#
# - **Body Type (`body_type`):**
#   - 5 categories (Hatchback, Sedan, SUV, etc.).
#   - **~1.4% missing values**.
#
# - **Transmission (`transmission`):**
#   - Manual/Automatic.
#   - **~7.5% missing values**.
#
# - **Registered City/State:**
#   - `registered_city`: 243 unique values → wide variety of registrations.
#   - `registered_state`: 16 unique states.
#   - Minimal missing (<0.2%).
#
# - **Source (`source`):**
#   - 3 platforms.
#   - ~1.7% missing values.
#
# - **Car Availability (`car_availability`):**
#   - 4 categories (Available, Sold, etc.).
#   - **~8.4% missing values**.
#
# - **Car Rating (`car_rating`):**
#   - 4 categories (Excellent, Good, Fair, Poor).
#   - Very few missing values (<0.2%).
#
# - **Fitness Certificate (`fitness_certificate`):**
#   - True/False.
#   - Very few missing (~0.1%).
#
# - **Boolean Flags:**
#   - `assured_buy`, `is_hot`, `reserved`, `warranty_avail` → clean (no missing).
#
# ---
#
# ## 📊 Missing Value Summary
#
# - **High Missingness:**
#   - `original_price` → **44.3% missing**.
#
# - **Moderate Missingness:**
#   - `car_availability` → 8.4% missing.
#   - `transmission` → 7.5% missing.
#
# - **Low Missingness (<2%):**
#   - `body_type`, `source`, `registered_city`, `registered_state`, `car_rating`, `fitness_certificate`, `ad_created_on`.
#
# - **No Missing:**
#   - Core columns like `car_name`, `yr_mfr`, `fuel_type`, `kms_run`, `sale_price`, `make`, `model`, `broker_quote`.
#
# ---
#
# ## ✅ Key Observations
#
# 1. **Target Variable:** `sale_price` → wide range, highly skewed, needs log-scaling.
# 2. **Missing Values:** Significant only in `original_price`, moderate in `car_availability` and `transmission`.
# 3. **High Cardinality Columns:** `variant` (943), `registered_city` (243), `car_name` (185).
# 4. **Potential Feature Leakage:** `broker_quote` is strongly correlated with `sale_price`.
# 5. **Temporal Aspect:** `ad_created_on` can be useful for seasonal/demand analysis.
# 6. **Boolean Flags (`is_hot`, `assured_buy`, etc.)** are useful for classification tasks.
# 7. **Financing Features (`emi_starts_from`, `booking_down_pymnt`)** can help model affordability-related pricing.
#
# ---
